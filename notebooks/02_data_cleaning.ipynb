# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# ## Objective
#
# The purpose of this step is to verify data quality and perform minimal cleaning if necessary.
#
# This step primarily focuses on data validation rather than extensive cleaning, as the dataset appears to be well-structured.

# %%
import pandas as pd
df = pd.read_csv("../data/raw/climate_change_impact_on_agriculture_2024.csv")

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check data types again
df.dtypes
# Out:
# Year                             int64
# Country                         object
# Region                          object
# Crop_Type                       object
# Average_Temperature_C          float64
# Total_Precipitation_mm         float64
# CO2_Emissions_MT               float64
# Crop_Yield_MT_per_HA           float64
# Extreme_Weather_Events           int64
# Irrigation_Access_%            float64
# Pesticide_Use_KG_per_HA        float64
# Fertilizer_Use_KG_per_HA       float64
# Soil_Health_Index              float64
# Adaptation_Strategies           object
# Economic_Impact_Million_USD    float64
# dtype: object

# %%
# Check basic statistics
df.describe()
# Out:
#                Year  Average_Temperature_C  Total_Precipitation_mm  \
# count  10000.000000           10000.000000            10000.000000
# mean    2007.088700              15.241299             1611.663834
# std       10.084245              11.466955              805.016815
# min     1990.000000              -4.990000              200.150000
# 25%     1999.000000               5.430000              925.697500
# 50%     2007.000000              15.175000             1611.160000
# 75%     2016.000000              25.340000             2306.997500
# max     2024.000000              35.000000             2999.670000
#
#        CO2_Emissions_MT  Crop_Yield_MT_per_HA  Extreme_Weather_Events  \
# count      10000.000000          10000.000000            10000.000000
# mean          15.246608              2.240017                4.980900
# std            8.589423              0.998342                3.165808
# min            0.500000              0.450000                0.000000
# ...

# %%
# Example: ensure no negative values in yield
(df["Crop_Yield_MT_per_HA"] < 0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Cleaning Summary
#
# - No missing values were found.
# - No major data quality issues were identified.
# - The dataset is clean and ready for exploratory analysis.
#
# Only minimal validation was required, and no substantial cleaning steps were necessary.
#
# This suggests that the dataset may have been pre-processed or synthetically generated, which is important to consider when interpreting results.
