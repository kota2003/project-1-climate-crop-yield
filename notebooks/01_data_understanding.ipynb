# %% [markdown]
# # 1. Data Understanding
# ## Climate Factors and Crop Yield Analysis

# %% [markdown]
# ## Objective
#
# The goal of this notebook is to understand the structure, variables, and overall quality of the dataset before performing any analysis.

# %% [markdown]
# ## Data Loading

# %%
import pandas as pd

df = pd.read_csv("../data/raw/climate_change_impact_on_agriculture_2024.csv")

df.head()
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %% [markdown]
# ## Basic Information
#
# The following section provides a structural overview of the dataset, including dimensions, variable names, data types, and missing values.
#
# This step helps verify the overall structure and quality of the dataset before deeper analysis.

# %%
df.shape
df.columns
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         10000 non-null  int64
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
# ...

# %% [markdown]
# ## Initial Observations
#
# - The dataset contains 10,000 rows and 15 columns.
# - There are no missing values across all variables.
# - The target variable is `Crop_Yield_MT_per_HA`.
# - Key climate variables include temperature, precipitation, CO2 emissions, and extreme weather events.
# - The dataset includes both numerical and categorical variables, enabling grouped analysis.
# - The data appears clean and structured, which supports efficient exploratory analysis.
# - The dataset is well-structured and suitable for exploratory analysis of climate–yield relationships.
#
# These characteristics suggest that the dataset is well-suited for relationship-focused exploratory analysis, particularly between climate variables and crop yield.
